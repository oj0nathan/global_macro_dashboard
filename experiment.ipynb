# %%
# %pip install -U nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from jsonschema>=2.6->nbformat) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.8)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (6.5.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from plotly) (2.14.0)
# Requirement already satisfied: packaging in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from plotly) (23.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (0.10.0)
# Requirement already satisfied: lxml in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from pandas_datareader) (5.4.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from pandas_datareader) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from pandas_datareader) (2.31.0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from pandas>=0.23->pandas_datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from pandas>=0.23->pandas_datareader) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jonat\anaconda3\envs\investsys\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2025.6.15)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np 
from pandas_datareader import data as web
import yfinance as yf

import plotly.io as pio
pio.renderers.default = "notebook_connected"  # good default for Jupyter
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
START = "2000-01-01"

FRED = {
    # Growth
    "INDPRO":   "Industrial Production",
    "PAYEMS":   "Nonfarm Payrolls",
    "UNRATE":   "Unemployment Rate",
    "ICSA":     "Initial Claims",
    "RSAFS":    "Retail Sales",

    # ISM PMI (NAPM) removed from FRED so replace with free survey proxies 
    "GACDISA066MSFRBNY": "NY Fed Empire: General Business Conditions (diffusion)",
    "GACDFSA066MSFRBPHI": "Philly Fed: Current General Activity (diffusion)",

    # Inflation
    "CPILFESL": "Core CPI",
    "PCEPILFE": "Core PCE",
    "CES0500000003": "Avg Hourly Earnings",

    # Liquidity / financial conditions / credit
    "WALCL":    "Fed Balance Sheet",
    "RRPONTSYD":"ON RRP",
    "WTREGEN":  "Treasury General Account (TGA)",
    "NFCI":     "Chicago Fed NFCI",
    "BAMLH0A0HYM2": "HY OAS",
}

BUCKETS = {
    "growth":   [
        "INDPRO","PAYEMS","UNRATE","ICSA","RSAFS",
        "GACDISA066MSFRBNY","GACDFSA066MSFRBPHI"
    ],
    "inflation":["CPILFESL","PCEPILFE","CES0500000003"],
    "liquidity":["WALCL","RRPONTSYD","WTREGEN","NFCI","BAMLH0A0HYM2"],
}

# +1 means "higher value = better growth / more inflation / easier liquidity"
# -1 means invert (higher value = worse growth or tighter liquidity)
SIGN = {
    # Growth
    "INDPRO": +1,
    "PAYEMS": +1,
    "UNRATE": -1,
    "ICSA":   -1,
    "RSAFS":  +1,
    "GACDISA066MSFRBNY": +1,
    "GACDFSA066MSFRBPHI": +1,

    # Inflation
    "CPILFESL": +1,
    "PCEPILFE": +1,
    "CES0500000003": +1,

    # Liquidity / conditions / credit
    "WALCL": +1,
    "RRPONTSYD": -1,
    "WTREGEN":  -1,
    "NFCI":     -1,
    "BAMLH0A0HYM2": -1,
}

ASSETS = ["SPY","TLT","GLD","UUP","HYG"]

# %%
def fetch_fred(codes, start=START):
    df = pd.DataFrame()
    for code in codes:
        s = web.DataReader(code, "fred", start)[code]
        df[code] = s
    return df

raw = fetch_fred(list(FRED.keys()), START)

# Put everything on a monthly grid (month-end "state")
m = raw.resample("ME").last()
m.tail()
# Out:
#               INDPRO  PAYEMS  UNRATE      ICSA     RSAFS  GACDISA066MSFRBNY  \
# DATE
# 2025-07-31  101.8738  159511     4.2       NaN  727727.0                5.5
# 2025-08-31  101.6019  159485     4.3       NaN  731700.0               11.9
# 2025-09-30  101.6729  159593     4.4       NaN  732444.0               -8.7
# 2025-10-31  101.6160  159488     NaN       NaN  732633.0               10.7
# 2025-11-30  101.7935  159552     4.6  229000.0       NaN               18.7
#
#             GACDFSA066MSFRBPHI  CPILFESL  PCEPILFE  CES0500000003      WALCL  \
# DATE
# 2025-07-31                15.9   328.656   126.426          36.43        NaN
# 2025-08-31                -0.3   329.793   126.707          36.58        NaN
# 2025-09-30                23.2   330.542   126.955          36.65        NaN
# 2025-10-31               -12.8       NaN       NaN          36.81  6587119.0
# 2025-11-30                -1.7   331.068       NaN          36.86        NaN
#
#             RRPONTSYD   WTREGEN     NFCI  BAMLH0A0HYM2
# DATE
# 2025-07-31    245.530       NaN      NaN          2.91
# 2025-08-31     97.426       NaN -0.52147          3.13
# 2025-09-30        NaN       NaN      NaN          2.84
# 2025-10-31     10.179  805139.0      NaN          2.81
# 2025-11-30        NaN       NaN      NaN           NaN

# %%
# 0) Defensive cleaning: Ensure no duplicate index issues before resampling
raw = raw.sort_index()
raw = raw[~raw.index.duplicated(keep="last")]

# 1) Daily calendar grid
raw_d = raw.asfreq("D")

# 2) Carry the last known "state" forward (Fixes Weekends & Holidays)
raw_d = raw_d.ffill()

# 3) Handle Pre-History for RRP
# Essential for calculating "Net Liquidity" (Fed Bal Sheet - TGA - RRP) back to 2000.
# Without this, your liquidity formula will be NaN for 13 years.
if "RRPONTSYD" in raw_d.columns:
    raw_d["RRPONTSYD"] = raw_d["RRPONTSYD"].fillna(0.0)

# 4) Month-end snapshot
m = raw_d.resample("ME").last()

m
# Out:
#               INDPRO    PAYEMS  UNRATE      ICSA     RSAFS  GACDISA066MSFRBNY  \
# DATE
# 2000-01-31   91.5380  131011.0     4.0  286000.0  261545.0                NaN
# 2000-02-29   91.8239  131121.0     4.1  286000.0  265686.0                NaN
# 2000-03-31   92.1504  131604.0     4.0  286000.0  269019.0                NaN
# 2000-04-30   92.6989  131883.0     3.8  266000.0  264067.0                NaN
# 2000-05-31   92.9499  132105.0     4.0  266000.0  265992.0                NaN
# ...              ...       ...     ...       ...       ...                ...
# 2025-07-31  101.8738  159511.0     4.2  224000.0  727727.0                5.5
# 2025-08-31  101.6019  159485.0     4.3  224000.0  731700.0               11.9
# 2025-09-30  101.6729  159593.0     4.4  224000.0  732444.0               -8.7
# 2025-10-31  101.6160  159488.0     4.4  224000.0  732633.0               10.7
# 2025-11-30  101.7935  159552.0     4.6  229000.0  732633.0               18.7
#
#             GACDFSA066MSFRBPHI  CPILFESL  PCEPILFE  CES0500000003      WALCL  \
# DATE
# 2000-01-31                11.2   179.300    74.306            NaN        NaN
# 2000-02-29                14.5   179.400    74.415            NaN        NaN
# 2000-03-31                19.4   180.000    74.568            NaN        NaN
# 2000-04-30                10.0   180.300    74.617            NaN        NaN
# 2000-05-31                13.9   180.700    74.697            NaN        NaN
# ...                        ...       ...       ...            ...        ...
# 2025-07-31                15.9   328.656   126.426          36.43  6852491.0
# 2025-08-31                -0.3   329.793   126.707          36.58  6852491.0
# 2025-09-30                23.2   330.542   126.955          36.65  6852491.0
# 2025-10-31               -12.8   330.542   126.955          36.81  6587119.0
# 2025-11-30                -1.7   331.068   126.955          36.86  6587119.0
#
#             RRPONTSYD   WTREGEN     NFCI  BAMLH0A0HYM2
# DATE
# 2000-01-31      0.000       NaN      NaN           NaN
# 2000-02-29      0.000       NaN      NaN          4.87
# 2000-03-31      0.000       NaN      NaN          5.11
# 2000-04-30      0.000       NaN      NaN          5.11
# 2000-05-31      0.000       NaN      NaN          5.83
# ...               ...       ...      ...           ...
# 2025-07-31    245.530  719873.0 -0.45124          2.91
# 2025-08-31     97.426  719873.0 -0.52147          3.13
# 2025-09-30     97.426  719873.0 -0.52147          2.84
# 2025-10-31     10.179  805139.0 -0.52147          2.81
# 2025-11-30     10.179  805139.0 -0.52147          2.81
#
# [311 rows x 15 columns]

# %%
missing_pct = (m.isna().mean() * 100).sort_values(ascending=False).round(2)
missing_pct
# Out:
# CES0500000003         23.79
# WALCL                 11.58
# WTREGEN               11.58
# GACDISA066MSFRBNY      5.79
# NFCI                   2.57
# BAMLH0A0HYM2           0.32
# INDPRO                 0.00
# PAYEMS                 0.00
# UNRATE                 0.00
# ICSA                   0.00
# RSAFS                  0.00
# GACDFSA066MSFRBPHI     0.00
# CPILFESL               0.00
# PCEPILFE               0.00
# RRPONTSYD              0.00
# dtype: float64

# %%
# Signals & Rolling Z scores (robust to flat series thayt early RRP)
def yoy(x):
    return x.pct_change(12) * 100

def delta_3m(x):
    return x - x.shift(3)

def rolling_z(x, window=120, min_periods=60):
    mu = x.rolling(window, min_periods=min_periods).mean()
    sd = x.rolling(window, min_periods=min_periods).std(ddof=0)
    sd = sd.replace(0, np.nan)  # IMPORTANT: as this prevents inf when series is flat (e.g., RRP=0 for years)
    return (x - mu) / sd

# Transform rules (simple + sensible for V1)
USE_YOY = {
    "INDPRO", "PAYEMS", "RSAFS",
    "CPILFESL", "PCEPILFE", "CES0500000003",
    "WALCL"  # optional; if you prefer level/change instead, remove it
}

USE_LEVEL = {
    "GACDISA066MSFRBNY", "GACDFSA066MSFRBPHI",   # surveys are already stationary-ish
    "NFCI", "BAMLH0A0HYM2",                      # conditions/spreads: level is meaningful
    "RRPONTSYD", "WTREGEN",                      # stocks / balances
}

# everything else defaults to 3M change (UNRATE, ICSA)
signals = pd.DataFrame(index=m.index)
zscores = pd.DataFrame(index=m.index)

for code in m.columns:
    x = m[code]

    if code in USE_YOY:
        sig = yoy(x)
    elif code in USE_LEVEL:
        sig = x
    else:
        sig = delta_3m(x)

    # Apply sign convention so "higher = better growth / more inflation / easier liquidity"
    if code in SIGN:
        sig = SIGN[code] * sig

    signals[code] = sig
    zscores[code] = rolling_z(sig, window=120, min_periods=60)

signals.tail(), zscores.tail()
# Out:
# (              INDPRO    PAYEMS  UNRATE    ICSA     RSAFS  GACDISA066MSFRBNY  \
#  DATE
#  2025-07-31  1.898561  0.954412    -0.0    -0.0  4.134309                5.5
#  2025-08-31  1.165976  0.892620    -0.1    -0.0  4.972606               11.9
#  2025-09-30  1.868079  0.807888    -0.3    -0.0  4.180185               -8.7
#  2025-10-31  2.157948  0.713573    -0.2    -0.0  3.469007               10.7
#  2025-11-30  2.518821  0.588202    -0.3 -5000.0  2.876942               18.7
#
#              GACDFSA066MSFRBPHI  CPILFESL  PCEPILFE  CES0500000003      WALCL  \
#  DATE
#  2025-07-31                15.9  3.048603  2.859793       3.877958  -6.926788
#  2025-08-31                -0.3  3.112191  2.906731       3.831961  -6.926788
#  2025-09-30                23.2  3.025543  2.825879       3.736202  -6.926788
#  2025-10-31               -12.8  2.752356  2.521965       3.748591 -10.531175
#  2025-11-30                -1.7  2.618879  2.414450       3.510250 -10.531175
#
#              RRPONTSYD   WTREGEN     NFCI  BAMLH0A0HYM2
#  DATE
#  2025-07-31   -245.530 -719873.0  0.45124         -2.91
#  2025-08-31    -97.426 -719873.0  0.52147         -3.13
#  2025-09-30    -97.426 -719873.0  0.52147         -2.84
#  2025-10-31    -10.179 -805139.0  0.52147         -2.81
#  2025-11-30    -10.179 -805139.0  0.52147         -2.81  ,
#                INDPRO    PAYEMS    UNRATE      ICSA     RSAFS  \
#  DATE
#  2025-07-31  0.485270 -0.099684 -0.017771 -0.008552 -0.176142
#  2025-08-31  0.300087 -0.115179 -0.074069 -0.008043 -0.055531
#  2025-09-30  0.463859 -0.137536 -0.189609 -0.007534 -0.175140
#  2025-10-31  0.525287 -0.162392 -0.128379 -0.007025 -0.282930
#  2025-11-30  0.601987 -0.196272 -0.186122 -0.037316 -0.372334
#
#              GACDISA066MSFRBNY  GACDFSA066MSFRBPHI  CPILFESL  PCEPILFE  \
#  DATE
#  2025-07-31           0.173588            0.347990 -0.006494  0.172679
#  2025-08-31           0.543367           -0.535566  0.029562  0.197617
#  2025-09-30          -0.690857            0.737156 -0.035818  0.128947
#  2025-10-31           0.459455           -1.223092 -0.227310 -0.104387
#  2025-11-30           0.924574           -0.619426 -0.322643 -0.192685
#
#              CES0500000003     WALCL  RRPONTSYD   WTREGEN      NFCI  \
#  DATE
#  2025-07-31       0.092179 -0.594477   0.359198 -0.316812  0.173600
#  2025-08-31       0.040928 -0.587171   0.559518 -0.308495  0.536631
#  2025-09-30      -0.054048 -0.579909   0.559705 -0.300170  0.538853
#  2025-10-31      -0.052410 -0.729190   0.676644 -0.476805  0.541081
#  2025-11-30      -0.274031 -0.723791   0.675600 -0.467057  0.543316
#
#              BAMLH0A0HYM2
#  DATE
#  2025-07-31      1.116559
#  2025-08-31      0.921158
#  2025-09-30      1.140475
#  2025-10-31      1.152008
#  2025-11-30      1.139565  )

# %%
def composite_z(df_z, members, min_k=None):
    members = [c for c in members if c in df_z.columns]
    sub = df_z[members]

    if min_k is None:
        # require at least half the bucket, minimum 2
        min_k = max(2, len(members)//2)

    count = sub.count(axis=1)
    score = sub.mean(axis=1, skipna=True)
    return score.where(count >= min_k)

scores = pd.DataFrame(index=zscores.index)
scores["growth"]    = composite_z(zscores, BUCKETS["growth"])
scores["inflation"] = composite_z(zscores, BUCKETS["inflation"])
scores["liquidity"] = composite_z(zscores, BUCKETS["liquidity"])

scores.tail()
# Out:
#               growth  inflation  liquidity
# DATE
# 2025-07-31  0.100671   0.086121   0.147614
# 2025-08-31  0.007867   0.089369   0.224328
# 2025-09-30  0.000048   0.013027   0.271791
# 2025-10-31 -0.117011  -0.128036   0.232748
# 2025-11-30  0.016441  -0.263120   0.233527

# %%
def regime_label(g, i):
    if pd.isna(g) or pd.isna(i):
        return np.nan
    if g >= 0 and i >= 0: return "Reflation (G↑ I↑)"
    if g >= 0 and i <  0: return "Goldilocks (G↑ I↓)"
    if g <  0 and i >= 0: return "Stagflation (G↓ I↑)"
    return "Deflation (G↓ I↓)"

regime = pd.Series(
    [regime_label(g, i) for g, i in zip(scores["growth"], scores["inflation"])],
    index=scores.index,
    name="regime"
)

regime.value_counts(dropna=True)
# Out:
# regime
# Reflation (G↑ I↑)      78
# Stagflation (G↓ I↑)    74
# Goldilocks (G↑ I↓)     60
# Deflation (G↓ I↓)      28
# Name: count, dtype: int64

# %%
import plotly.io as pio
import plotly.graph_objects as go
pio.renderers.default = "vscode"

fig = go.Figure()
for c in ["growth", "inflation", "liquidity"]:
    fig.add_trace(go.Scatter(x=scores.index, y=scores[c], mode="lines", name=f"{c.title()} (z)"))

fig.add_hline(y=0)
fig.update_layout(
    title="Macro Tape — Growth / Inflation / Liquidity (rolling z composites)",
    hovermode="x unified",
    height=420
)
fig.show()

# %%
px_m = yf.download(ASSETS, start=START, auto_adjust=True, progress=False)["Close"].resample("M").last()
ret_1m = px_m.pct_change(1) * 100

df = pd.concat([regime, ret_1m], axis=1).dropna()
display(df.groupby("regime")[ASSETS].mean().round(2))
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_17144\1751228582.py:1: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#                       SPY   TLT   GLD   UUP   HYG
# regime
# Deflation (G↓ I↓)    0.78 -0.07  1.17 -0.27  1.12
# Goldilocks (G↑ I↓)   1.07  0.68  0.25  0.11  0.50
# Reflation (G↑ I↑)    0.76  0.44  0.75  0.40  0.21
# Stagflation (G↓ I↑)  1.07  0.14  1.50  0.16  0.34

# %%
import plotly.express as px

df_scatter = (
    scores.assign(regime=regime)
    .dropna(subset=["growth","inflation","regime"])
    .reset_index()          # creates a DATE column (based on your screenshot)
)

fig = px.scatter(
    df_scatter,
    x="growth", y="inflation",
    color="regime",
    hover_data=["DATE"],
    title="Growth vs Inflation — Regime Map"
)
fig.add_hline(y=0); fig.add_vline(x=0)
fig.show()

# %%
import yfinance as yf
import plotly.express as px

px_m = yf.download(ASSETS, start=START, auto_adjust=True, progress=False)["Close"].resample("M").last()
ret_1m = px_m.pct_change(1) * 100
ret_3m = px_m.pct_change(3) * 100

df = pd.concat([regime, ret_1m.add_prefix("1m_"), ret_3m.add_prefix("3m_")], axis=1).dropna()

by_regime_1m = df.groupby("regime")[[f"1m_{a}" for a in ASSETS]].mean().round(2)
fig = px.imshow(by_regime_1m.values, x=by_regime_1m.columns, y=by_regime_1m.index,
                text_auto=True, aspect="auto", title="Avg 1M Returns by Regime (%)")
fig.show()
# Out:
# C:\Users\jonat\AppData\Local\Temp\ipykernel_17144\3582168988.py:4: FutureWarning:
#
# 'M' is deprecated and will be removed in a future version, please use 'ME' instead.

# %%
import plotly.express as px

last = zscores.dropna(how="all").index[-1]

drivers = (
    zscores.loc[last].dropna()
    .rename("z").to_frame()
    .assign(name=lambda d: d.index.map(lambda c: FRED.get(c, c)))
    .sort_values("z", ascending=False)
    .reset_index().rename(columns={"index":"code"})
)

fig = px.bar(drivers.head(12), x="z", y="name", orientation="h",
             title=f"Top +Z Drivers (as of {last.date()})")
fig.show()

fig = px.bar(drivers.tail(12), x="z", y="name", orientation="h",
             title=f"Top -Z Drivers (as of {last.date()})")
fig.show()

# %%
regime.value_counts()
# Out:
# regime
# Reflation (G↑ I↑)      78
# Stagflation (G↓ I↑)    74
# Goldilocks (G↑ I↓)     60
# Deflation (G↓ I↓)      28
# Name: count, dtype: int64

# %%
df_reg = pd.DataFrame({"regime": regime, "g": scores["growth"], "i": scores["inflation"]}).dropna()
df_reg[df_reg["regime"].str.contains("Deflation")].tail(24)
# Out:
#                        regime         g         i
# DATE
# 2009-01-31  Deflation (G↓ I↓) -3.236839 -2.157273
# 2009-02-28  Deflation (G↓ I↓) -2.842057 -1.946574
# 2009-03-31  Deflation (G↓ I↓) -2.738507 -2.036042
# 2009-04-30  Deflation (G↓ I↓) -2.350955 -1.591700
# 2009-05-31  Deflation (G↓ I↓) -2.096718 -1.761619
# 2009-06-30  Deflation (G↓ I↓) -1.735614 -1.969044
# 2009-07-31  Deflation (G↓ I↓) -1.487560 -2.210992
# 2009-08-31  Deflation (G↓ I↓) -1.175283 -2.212638
# 2009-09-30  Deflation (G↓ I↓) -0.937003 -2.018727
# 2009-10-31  Deflation (G↓ I↓) -0.787985 -1.181290
# 2009-11-30  Deflation (G↓ I↓) -0.298463 -1.025551
# 2009-12-31  Deflation (G↓ I↓) -0.182085 -0.748598
# 2012-06-30  Deflation (G↓ I↓) -0.045439 -0.111887
# 2012-07-31  Deflation (G↓ I↓) -0.024153 -0.349567
# 2012-12-31  Deflation (G↓ I↓) -0.048636 -0.251319
# 2013-01-31  Deflation (G↓ I↓) -0.159353 -0.336225
# 2015-06-30  Deflation (G↓ I↓) -0.042899 -0.566265
# 2015-09-30  Deflation (G↓ I↓) -0.154154 -0.361392
# 2015-10-31  Deflation (G↓ I↓) -0.230589 -0.237778
# 2015-11-30  Deflation (G↓ I↓) -0.313041 -0.237911
# 2015-12-31  Deflation (G↓ I↓) -0.299247 -0.109644
# 2020-06-30  Deflation (G↓ I↓) -1.772083 -0.368517
# 2025-04-30  Deflation (G↓ I↓) -0.370970 -0.021112
# 2025-10-31  Deflation (G↓ I↓) -0.117011 -0.128036
